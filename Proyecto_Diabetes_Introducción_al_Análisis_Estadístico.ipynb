# %% [markdown]
# <a href="https://colab.research.google.com/github/ElihuIzanami/Introduccion-Analisis-Exploratorio-Datos-Proyecto-3-Final/blob/main/Proyecto_Diabetes_Introducci%C3%B3n_al_An%C3%A1lisis_Estad%C3%ADstico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PROYECTO: INTRODUCCIÓN AL ANÁLISIS ESTADÍSTICO**

# %% [markdown]
# Una vez visto el ***Módulo 2: Fundamentos Estadísticos***, se presenta la siguiente actividad para que el alumnado pueda poner a prueba lo aprendido durante este módulo.

# %% [markdown]
# Dentro de la siguiente dinámica, realizar el siguiente **análisis exploratorio con aprendizaje estadístico** de cualquier dataset proveniente de la librería de ***Seaborn*** que no haya sido utilizado.
#
# Se sugiere los siguientes puntos para llevar a cabo lo anterior:
#
# *   Realizar un **análisis descriptivo** para comprender comportamiento de la descripción de los datos a través de resúmenes.
# *   Realizar un **aprendizaje estadístico** para predecir comportamientos lineales de datos a través de la regresión lineal simple.

# %% [markdown]
# ***El dataset que se ocupo para el Proyecto : Introduccion al analisis Estadistico se descargo de la pagina de www.kaggle.com a continuación se enlista la url donde se descargo dicho archivo .cvs***
# https://www.kaggle.com/datasets/mathchi/diabetes-data-set

# %%
#Importacion de librerias
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime

# %%
# Importar datos desde Google Colab
ruta = '/content/diabetes.csv'
df_diabetes = pd.read_csv(ruta)

df_diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df_diabetes.shape
# Out:
# (768, 9)

# %%
# Obtenermos la información del dataset
df_diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# Verificar valores nulos por columna
print(df_diabetes.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#para ver que no vengan valores vacios o nullos
df_diabetes.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ***ANALISIS UNIVARIABLE***

# %%
# Mostrar resumen estadístico
df_diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# Realizar una proporción de probabilidad

media = round(df_diabetes.describe()['Glucose']['mean'], 4)
std= round(df_diabetes.describe()['Glucose']['std'], 4)
prop_prob = round((std/media)*100, 1)

print(f'Los datos se separan de la medía a un {prop_prob}%')
# Out:
# Los datos se separan de la medía a un 26.4%

# %% [markdown]
# ***MEDIDAS DE TENDENCIA CENTRAL***

# %%
# Definir variables

media = round(df_diabetes['Glucose'].mean(), 2)
mediana = round(df_diabetes['Glucose'].median(), 2)
moda = round(df_diabetes['Glucose'].mode().iloc[0], 2)

print(f'Las MTC son: media {media}, mediana {mediana} y moda {moda}')
# Out:
# Las MTC son: media 120.89, mediana 117.0 y moda 99

# %%
# Definir variables Glucosa
media_glc = round(df_diabetes['Glucose'].mean(),2)
mediana_glc = round(df_diabetes['Glucose'].median(),2)
moda_glc = df_diabetes['Glucose'].mode()[0]

# %%
# Definir listas Glucosa
mtc_datos_glc = [media_glc, mediana_glc, moda_glc]
mtc_colores_glc = ['blue', 'red', 'green']
mtc_etiquetas_glc = ['media', 'mediana', 'moda']

# %%
#Grafica de Histograma de la Glucosa
plt.hist(df_diabetes['Glucose'], edgecolor = 'black',color = 'whitesmoke')
plt.title('Glucosa Distribucion')
plt.xlabel('Glucosa')
plt.ylabel('Frecuencia')

for dato, color, etiqueta in zip(mtc_datos_glc, mtc_colores_glc, mtc_etiquetas_glc):
    plt.axvline(x = dato, c = color, linestyle = '--', label = f'{etiqueta}: {dato}')
#plt.axvline(x = dato, c = color, linestyle = '--', label = f'{etiqueta}: {dato}')

plt.legend()
plt.show()

# %%
# Gráfico de distribución de la glucosa
plt.figure(figsize=(8, 5))
sns.histplot(df_diabetes['Glucose'], kde=True, color='blue')
plt.title('Distribución de los niveles de Glucosa')
plt.xlabel('Glucosa')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Definir variables Insulina
media_ins = round(df_diabetes['Insulin'].mean(),2)
mediana_ins = round(df_diabetes['Insulin'].median(),2)
moda_ins = df_diabetes['Insulin'].mode()[0]

# %%
# Definir listas Insulina
mtc_datos_ins = [media_glc, mediana_glc, moda_glc]
mtc_colores_ins = ['blue', 'red', 'green']
mtc_etiquetas_ins = ['media', 'mediana', 'moda']

# %%
# Definir listas Insulina
mtc_datos_ptl = [media_glc, mediana_glc, moda_glc]
mtc_colores_ptl = ['blue', 'red', 'green']
mtc_etiquetas_ptl = ['media', 'mediana', 'moda']

# %%
#Grafica de Histograma de la Insulina
plt.hist(df_diabetes['Insulin'], edgecolor = 'black',color = 'whitesmoke')
plt.title('Insulina Distribucion')
plt.xlabel('Insulina')
plt.ylabel('Frecuencia')

for dato, color, etiqueta in zip(mtc_datos_glc, mtc_colores_glc, mtc_etiquetas_glc):
    plt.axvline(x = dato, c = color, linestyle = '--', label = f'{etiqueta}: {dato}')
#plt.axvline(x = dato, c = color, linestyle = '--', label = f'{etiqueta}: {dato}')

plt.legend()
plt.show()

# %%
# Gráfico de distribución de la Insulina
plt.figure(figsize=(8, 5))
sns.histplot(df_diabetes['Insulin'], kde=True, color='blue')
plt.title('Distribución de los niveles de Insulina')
plt.xlabel('Insulin')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ***Funciones y Graficos de la Diabetes en Insulina***

# %%
#Grafica de la Insulina vs Glucosa
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_diabetes, x='Glucose', y='Insulin', hue='Outcome')
plt.title('Gráfico de Dispersion Insulina')
plt.xlabel('Insulina')
plt.ylabel('Diabetes')
plt.legend()
plt.show()

# %% [markdown]
# ***DESVIACION ESTANDAR***

# %%
#std glucosa
# Definir variables
x_glc = range(len(df_diabetes['Glucose']))
y_glc = df_diabetes['Glucose']
std_glc = np.std(df_diabetes['Glucose'])

# %%
# Definir listas glucosa
std_datos_glc = [media_glc, mediana_glc + std_glc , media_glc - std_glc ]
std_colores_glc = ['red', 'blue', 'blue']
std_etiquetas_glc = ['mediana', 'desviacion standar', None]

# %%
#Grafica de dispersion de la glucosa
plt.scatter(x_glc, y_glc, color = 'gray', s = 5, label = 'datos')
plt.title('Dispersión de la Glucosa')
plt.xlabel('Indice')
plt.ylabel('Total')

for dato, color, etiqueta in zip(std_datos_glc, std_colores_glc, std_etiquetas_glc):
  plt.axhline(y = dato, c = color, linestyle = '--', label = etiqueta)

plt.legend()
plt.show()

# %%
#std insulina
# Definir variables
x_ins = range(len(df_diabetes['Insulin']))
y_ins = df_diabetes['Insulin']
std_ins = np.std(df_diabetes['Insulin'])

# %%
# Definir listas glucosa
std_datos_ins = [media_ins, mediana_ins + std_ins , media_ins - std_ins ]
std_colores_ins = ['red', 'blue', 'blue']
std_etiquetas_ins = ['mediana', 'desviacion standar', None]

# %%
#Grafica de dispersion de la insulina
plt.scatter(x_ins, y_ins, color = 'gray', s = 5, label = 'datos')
plt.title('Dispersión de la Insulina')
plt.xlabel('Indice')
plt.ylabel('Total')

for dato, color, etiqueta in zip(std_datos_ins, std_colores_ins, std_etiquetas_ins):
  plt.axhline(y = dato, c = color, linestyle = '--', label = etiqueta)

plt.legend()
plt.show()

# %% [markdown]
# ***PERCENTILES***

# %%
# Percentiles Glucosa
percentil = np.percentile(df_diabetes['Glucose'],[25,50,75])

q_1 = round(percentil[0],2)
q_3 = round(percentil[2],2)
iqr = round(q_3 - q_1,2)

# %%
# Visualizar percentiles Glucosa
plt.boxplot(df_diabetes['Glucose'], label= f'mediana: {mediana_glc}\nIQR: {iqr}')
plt.title('Grafico caja de la Glucosa')
plt.ylabel('Total Glucosa')
plt.legend()
plt.show()

# %%
# Asociar gráficos Glucosa
fig, ax = plt.subplots(3, figsize = (10, 10), gridspec_kw = {'hspace':0.5})

ax[0].boxplot(df_diabetes['Glucose'], vert = False)
ax[0].set_title('Gráfico de caja')
ax[0].set_xlabel('Total del Glucosa')


ax[1].hist(df_diabetes['Glucose'], edgecolor = 'black',color = 'whitesmoke')
ax[1].axvline(x = media_glc, color = 'blue', linestyle = '--')
ax[1].axvline(x = mediana_glc, color = 'red', linestyle = '--')
ax[1].set_title('Histograma')
ax[1].set_xlabel('Total de la Glucosa')

ax[2].scatter(y_glc, x_glc, color = 'gray', s = 5)
ax[2].axvline(x = media_glc, color = 'blue', linestyle = '--')
ax[2].axvline(x = mediana_glc, color = 'red', linestyle = '--')
ax[2].set_title('Gráfico de dispersión')
ax[2].set_xlabel('Total de la Glucosa')

plt.show()

# %%
# Percentiles Insulina
percentil = np.percentile(df_diabetes['Insulin'],[25,50,75])

q_1 = round(percentil[0],2)
q_3 = round(percentil[2],2)
iqr = round(q_3 - q_1,2)

# %%
# Visualizar percentiles Insulina
plt.boxplot(df_diabetes['Insulin'], label= f'mediana: {mediana_ins}\nIQR: {iqr}')
plt.title('Grafico caja de la Insulina')
plt.ylabel('Total del Insulina')
plt.legend()
plt.show()

# %%
# Asociar gráficos Insulina
fig, ax = plt.subplots(3, figsize = (10, 10), gridspec_kw = {'hspace':0.5})

ax[0].boxplot(df_diabetes['Insulin'], vert = False)
ax[0].set_title('Gráfico de caja')
ax[0].set_xlabel('Total de la Insulina')


ax[1].hist(df_diabetes['Insulin'], edgecolor = 'black',color = 'whitesmoke')
ax[1].axvline(x = media_ins, color = 'blue', linestyle = '--')
ax[1].axvline(x = mediana_ins, color = 'red', linestyle = '--')
ax[1].set_title('Histograma')
ax[1].set_xlabel('Total de la Insulina')

ax[2].scatter(y_ins, x_ins, color = 'gray', s = 5)
ax[2].axvline(x = media_ins, color = 'blue', linestyle = '--')
ax[2].axvline(x = mediana_ins, color = 'red', linestyle = '--')
ax[2].set_title('Gráfico de dispersión')
ax[2].set_xlabel('Total de la Insulina')

plt.show()

# %% [markdown]
# ***ANÁLISIS BIVARIABLE***

# %%
#Para el mapa de calor y coorelacion
columnas = ['Glucose', 'BloodPressure', 'Insulin', 'Age','BMI','Outcome']
correlacion = df_diabetes[columnas].corr()

long_col = len(columnas)

# %% [markdown]
# ***CORRELACION***

# %%
correlacion
# Out:
#                 Glucose  BloodPressure   Insulin       Age       BMI   Outcome
# Glucose        1.000000       0.152590  0.331357  0.263514  0.221071  0.466581
# BloodPressure  0.152590       1.000000  0.088933  0.239528  0.281805  0.065068
# Insulin        0.331357       0.088933  1.000000 -0.042163  0.197859  0.130548
# Age            0.263514       0.239528 -0.042163  1.000000  0.036242  0.238356
# BMI            0.221071       0.281805  0.197859  0.036242  1.000000  0.292695
# Outcome        0.466581       0.065068  0.130548  0.238356  0.292695  1.000000

# %%
correlacion
# Out:
#                 Glucose  BloodPressure   Insulin       Age       BMI   Outcome
# Glucose        1.000000       0.152590  0.331357  0.263514  0.221071  0.466581
# BloodPressure  0.152590       1.000000  0.088933  0.239528  0.281805  0.065068
# Insulin        0.331357       0.088933  1.000000 -0.042163  0.197859  0.130548
# Age            0.263514       0.239528 -0.042163  1.000000  0.036242  0.238356
# BMI            0.221071       0.281805  0.197859  0.036242  1.000000  0.292695
# Outcome        0.466581       0.065068  0.130548  0.238356  0.292695  1.000000

# %% [markdown]
# #### **MULTIVARIABLE**

# %%
# Visualizar mapa de calor
corr_inv = correlacion.iloc[::-1]
heatmap = plt.pcolor(correlacion, cmap = 'coolwarm', vmin = -1, vmax = 1)
plt.title('Mapa de calor')
plt.xticks(np.arange(0.5, long_col, 1), columnas)
plt.yticks(np.arange(0.5, long_col, 1), columnas[::-1])

for i in range(len(columnas)):
  for j in range(len(columnas)):
    val = round(corr_inv.iloc[i,j],2)
    plt.text(j + 0.5, i + 0.5, f'{val}',
             ha = 'center', va = 'center',
             color = 'white' if abs(val) > 0.6 else 'black')

   # print(val)

plt.colorbar(heatmap)
plt.tight_layout()
plt.show()

# %%
# Mapa de calor que muestra la correlación entre las variables numéricas del dataset
sns.heatmap(df_diabetes[columnas].corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# #### **BIVARIABLE**

# %%
# Definir variables
corr_glc_ins = round(df_diabetes['Glucose'].corr(df_diabetes['Insulin']),2),
corr_glc_blp = round(df_diabetes['Glucose'].corr(df_diabetes['BloodPressure']),2),
corr_blp_age =round(df_diabetes['BloodPressure'].corr(df_diabetes['Age']),2),

# %%
# Visualizar correlaciones
fig, ax = plt.subplots(1, 3, figsize = (20, 5), gridspec_kw = {'hspace': 0.5})

ax[0].scatter(data = df_diabetes, x = 'Glucose', y = 'Insulin', label = f'Pearson: {corr_glc_ins}')
ax[0].set_title('Glucose vs Insulia')
ax[0].set_xlabel('Glucosa')
ax[0].set_ylabel('Insulina')
ax[0].legend(loc = 'upper left')

ax[1].scatter(data = df_diabetes, x = 'Glucose', y = 'BloodPressure', color = 'orange', label = f'Pearson: {corr_glc_blp}')
ax[1].set_title('Glucosa vs Presion Sanguinea')
ax[1].set_xlabel('Glucosa')
ax[1].set_ylabel('Presion Sanguinea')
ax[1].legend(loc = 'upper left')

ax[2].scatter(data = df_diabetes, x = 'BloodPressure', y = 'Age', color = 'teal', label = f'Pearson: {corr_blp_age}')
ax[2].set_title('Presion Sanguinea vs Edad')
ax[2].set_xlabel('Presion Sanguinea')
ax[2].set_ylabel('Edad')
ax[2].legend(loc = 'upper left')

plt.show()

# %% [markdown]
# ***ANALISIS PREDICTIVO DE DATOS***

# %%
# Definir regresión lineal

x = df_diabetes['Glucose']
y = df_diabetes['Insulin']
n = len(x)

linear_regression = np.polyfit(x, y, 1)
beta, alpha = linear_regression

print(f'y = {beta:.2f} x + {alpha:.2f}')
# Out:
# y = 1.19 x + -64.59

# %%
# Realizar algoritmo del descenso de gradiente

tamaño_paso = 0.001
theta_0 = 0
theta_1 = 0

perdida = []
num_iteraciones = 100

for i in range(num_iteraciones):
    y_pred = theta_1 * x + theta_0
    error = ((y_pred - y) ** 2).mean()
    perdida.append(error)

    d_theta_0 = (2 / n) * np.sum(y_pred - y)
    d_theta_1 = (2 / n) * np.sum((y_pred - y) * x)

    theta_0 = theta_0 - tamaño_paso * d_theta_0
    theta_1 = theta_1 - tamaño_paso * d_theta_1

print(f'y = {theta_1:.2f} x + {theta_0:.2f}')
# Out:
# y = -8910197668685089579741124234643026341472263715226479511088765788620860855405486469293114811026077345672536551368481706795908714216961998190266023936.00 x + -68890430488855575415551752079170915746634376796895826829991943446017003590811398894933225352946328455729680456215105633046354946445258481133944832.00

# %%
# Predicción de valores con descenso de gradiente

glucosa = int(input('Agrega el valor d la glucosa: '))
pred_glc = round(theta_1 * glucosa + theta_0, 2)

print(f'La glucosa estimada sera {pred_glc}')
# Out:
# Agrega el valor d la glucosa: 125
# La glucosa estimada sera -1.1138435990161252e+150

# %%
#Para la Regresion Lineal
# import from sklearn the linear regression model that will help us in this analysis.

from sklearn.linear_model import LinearRegression

# Define X (independent variable) and y (dependent variable) for linear regression
X = df_diabetes['Glucose'].values.reshape(-1, 1) # Reshape to 2D array
y = df_diabetes['Insulin'].values

# create an empty linear regression model like below and give it a good variable name
linear_model = LinearRegression()

# to create the model, we use fit(X,y)
linear_model.fit(X, y)


y_pred = linear_model.predict(X)
plt.scatter(X, y, color = 'b', label='Actual data')
plt.plot(X, y_pred, color = 'r', label='Linear Regression')
plt.title('Linear Regression:Glucosa vs Insulina')
plt.xlabel('Glucosa Length')
plt.ylabel('Insulina Length')
plt.legend()
plt.show()

# %%
# Visualizar función de costo

plt.plot(perdida)
plt.xlabel('Iteración')
plt.ylabel('Pérdida')
plt.show()

# %%
# Crear un gráfico de dispersión y personalizalo con Matplotlib
sns.scatterplot(x = 'Age', y = 'Glucose', data = df_diabetes)
plt.title('Relación entre la Edad e IMC')
plt.xlabel('Edad del Paciente')
plt.ylabel('Glucosa %')
plt.grid()
